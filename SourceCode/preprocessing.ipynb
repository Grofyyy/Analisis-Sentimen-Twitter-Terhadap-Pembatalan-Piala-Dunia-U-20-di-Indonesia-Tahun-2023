# %% [markdown]
# # preprocessing

# %%
import pandas as pd
import re 
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\arman\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df = pd.read_csv("/Users/arman/Skripsi/Dataset/BigData/Fix/Piala-Dunia-Label.csv", encoding='utf-8')
df
# Out:
#                                                     Text    Label
# 0      @ch_chotimah2 @Dennysiregar7 @erickthohir @jok...  negatif
# 1      Gagalnya perhelatan piala dunia U-20 di Indone...  positif
# 2      @tatakujiyati Tapi @aniesbaswedan kan sering m...  negatif
# 3      Dicoret sebagai tuan rumah piala dunia U-20, b...   netral
# 4      Ketua umum Erick Thohir mengungkapkan alasan F...   netral
# ...                                                  ...      ...
# 14802  Piala Dunia U-20 Batal Digelar di Indonesia ht...   netral
# 14803  4 Tahun Perjuangan Indonesia Jadi Tuan Rumah P...  negatif
# 14804  @Metro_TV 3043 guru PI PPPK se-Indonesia dan T...   netral
# 14805  Pemain Timnas Indonesia U-20 ramai-ramai tumpa...  negatif
# 14806  Politikus PDIP Budiman Sudjatmiko mengatakan, ...  positif
#
# [14807 rows x 2 columns]

# %% [markdown]
# # Case folding

# %%
#Case Folding
df['CaseFolding'] = df['Text'].str.lower()
df.head()
# Out:
#                                                 Text    Label  \
# 0  @ch_chotimah2 @Dennysiregar7 @erickthohir @jok...  negatif
# 1  Gagalnya perhelatan piala dunia U-20 di Indone...  positif
# 2  @tatakujiyati Tapi @aniesbaswedan kan sering m...  negatif
# 3  Dicoret sebagai tuan rumah piala dunia U-20, b...   netral
# 4  Ketua umum Erick Thohir mengungkapkan alasan F...   netral
#
#                                          CaseFolding
# 0  @ch_chotimah2 @dennysiregar7 @erickthohir @jok...
# 1  gagalnya perhelatan piala dunia u-20 di indone...
# 2  @tatakujiyati tapi @aniesbaswedan kan sering m...
# 3  dicoret sebagai tuan rumah piala dunia u-20, b...
# 4  ketua umum erick thohir mengungkapkan alasan f...

# %% [markdown]
# # Celaning Data

# %%
# ------ CleanData ---------

def remove_tweet_special(text):
       
    #menghapus username twitter
    text = re.sub('@[^\s]+','',text)
    
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    
    #remove number
    text = re.sub(r"\d+", "", text)
    
    #remove punctuation
    text = text.translate(str.maketrans("","",string.punctuation))
    
    # remove white space
    text = text.strip()
    
    #remove multiple white space
    text = re.sub('\s+',' ',text)
    
    #remove single char
    text = re.sub(r"\b[a-zA-Z]\b", "", text)
    
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
    
                
df['TextClean'] = df['CaseFolding'].apply(remove_tweet_special)

# %%
df
# Out:
#                                                     Text    Label  \
# 0      @ch_chotimah2 @Dennysiregar7 @erickthohir @jok...  negatif
# 1      Gagalnya perhelatan piala dunia U-20 di Indone...  positif
# 2      @tatakujiyati Tapi @aniesbaswedan kan sering m...  negatif
# 3      Dicoret sebagai tuan rumah piala dunia U-20, b...   netral
# 4      Ketua umum Erick Thohir mengungkapkan alasan F...   netral
# ...                                                  ...      ...
# 14802  Piala Dunia U-20 Batal Digelar di Indonesia ht...   netral
# 14803  4 Tahun Perjuangan Indonesia Jadi Tuan Rumah P...  negatif
# 14804  @Metro_TV 3043 guru PI PPPK se-Indonesia dan T...   netral
# 14805  Pemain Timnas Indonesia U-20 ramai-ramai tumpa...  negatif
# 14806  Politikus PDIP Budiman Sudjatmiko mengatakan, ...  positif
#
#                                              CaseFolding  \
# 0      @ch_chotimah2 @dennysiregar7 @erickthohir @jok...
# 1      gagalnya perhelatan piala dunia u-20 di indone...
# 2      @tatakujiyati tapi @aniesbaswedan kan sering m...
# 3      dicoret sebagai tuan rumah piala dunia u-20, b...
# 4      ketua umum erick thohir mengungkapkan alasan f...
# ...                                                  ...
# 14802  piala dunia u-20 batal digelar di indonesia ht...
# 14803  4 tahun perjuangan indonesia jadi tuan rumah p...
# 14804  @metro_tv 3043 guru pi pppk se-indonesia dan t...
# 14805  pemain timnas indonesia u-20 ramai-ramai tumpa...
# 14806  politikus pdip budiman sudjatmiko mengatakan, ...
#
#                                                TextClean
# 0      lupakan kegagalan tuan rumah piala dunia  mari...
# 1      gagalnya perhelatan piala dunia  di indonesia ...
# 2      tapi kan sering mencitrakan diri sgt membela p...
# 3      dicoret sebagai tuan rumah piala dunia  bentar...
# 4      ketua umum erick thohir mengungkapkan alasan f...
# ...                                                  ...
# 14802            piala dunia  batal digelar di indonesia
# 14803  tahun perjuangan indonesia jadi tuan rumah pia...
# 14804  guru pi pppk seindonesia dan tuan rumah piala ...
# 14805  pemain timnas indonesia  ramairamai tumpahkan ...
# 14806  politikus pdip budiman sudjatmiko mengatakan p...
#
# [14807 rows x 4 columns]

# %% [markdown]
# ## Tokenizing

# %%
# Tokenzing
# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)
df['tokens'] =df['TextClean'].apply(word_tokenize_wrapper)
df
# Out:
#                                                     Text    Label  \
# 0      @ch_chotimah2 @Dennysiregar7 @erickthohir @jok...  negatif
# 1      Gagalnya perhelatan piala dunia U-20 di Indone...  positif
# 2      @tatakujiyati Tapi @aniesbaswedan kan sering m...  negatif
# 3      Dicoret sebagai tuan rumah piala dunia U-20, b...   netral
# 4      Ketua umum Erick Thohir mengungkapkan alasan F...   netral
# ...                                                  ...      ...
# 14802  Piala Dunia U-20 Batal Digelar di Indonesia ht...   netral
# 14803  4 Tahun Perjuangan Indonesia Jadi Tuan Rumah P...  negatif
# 14804  @Metro_TV 3043 guru PI PPPK se-Indonesia dan T...   netral
# 14805  Pemain Timnas Indonesia U-20 ramai-ramai tumpa...  negatif
# 14806  Politikus PDIP Budiman Sudjatmiko mengatakan, ...  positif
#
#                                              CaseFolding  \
# 0      @ch_chotimah2 @dennysiregar7 @erickthohir @jok...
# 1      gagalnya perhelatan piala dunia u-20 di indone...
# 2      @tatakujiyati tapi @aniesbaswedan kan sering m...
# 3      dicoret sebagai tuan rumah piala dunia u-20, b...
# 4      ketua umum erick thohir mengungkapkan alasan f...
# ...                                                  ...
# 14802  piala dunia u-20 batal digelar di indonesia ht...
# 14803  4 tahun perjuangan indonesia jadi tuan rumah p...
# 14804  @metro_tv 3043 guru pi pppk se-indonesia dan t...
# 14805  pemain timnas indonesia u-20 ramai-ramai tumpa...
# 14806  politikus pdip budiman sudjatmiko mengatakan, ...
#
#                                                TextClean  \
# 0      lupakan kegagalan tuan rumah piala dunia  mari...
# 1      gagalnya perhelatan piala dunia  di indonesia ...
# 2      tapi kan sering mencitrakan diri sgt membela p...
# 3      dicoret sebagai tuan rumah piala dunia  bentar...
# 4      ketua umum erick thohir mengungkapkan alasan f...
# ...                                                  ...
# 14802            piala dunia  batal digelar di indonesia
# 14803  tahun perjuangan indonesia jadi tuan rumah pia...
# 14804  guru pi pppk seindonesia dan tuan rumah piala ...
# 14805  pemain timnas indonesia  ramairamai tumpahkan ...
# 14806  politikus pdip budiman sudjatmiko mengatakan p...
#
#                                                   tokens
# 0      [lupakan, kegagalan, tuan, rumah, piala, dunia...
# 1      [gagalnya, perhelatan, piala, dunia, di, indon...
# 2      [tapi, kan, sering, mencitrakan, diri, sgt, me...
# 3      [dicoret, sebagai, tuan, rumah, piala, dunia, ...
# 4      [ketua, umum, erick, thohir, mengungkapkan, al...
# ...                                                  ...
# 14802      [piala, dunia, batal, digelar, di, indonesia]
# 14803  [tahun, perjuangan, indonesia, jadi, tuan, rum...
# 14804  [guru, pi, pppk, seindonesia, dan, tuan, rumah...
# 14805  [pemain, timnas, indonesia, ramairamai, tumpah...
# 14806  [politikus, pdip, budiman, sudjatmiko, mengata...
#
# [14807 rows x 5 columns]

# %% [markdown]
# ## Normalisasi

# %%
#normalisasi 

normalizad_word = pd.read_csv("/Users/arman/Skripsi/normalisasi.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df['normalisasi'] = df['tokens'].apply(normalized_term)

df
# Out:
#                                                     Text    Label  \
# 0      @ch_chotimah2 @Dennysiregar7 @erickthohir @jok...  negatif
# 1      Gagalnya perhelatan piala dunia U-20 di Indone...  positif
# 2      @tatakujiyati Tapi @aniesbaswedan kan sering m...  negatif
# 3      Dicoret sebagai tuan rumah piala dunia U-20, b...   netral
# 4      Ketua umum Erick Thohir mengungkapkan alasan F...   netral
# ...                                                  ...      ...
# 14802  Piala Dunia U-20 Batal Digelar di Indonesia ht...   netral
# 14803  4 Tahun Perjuangan Indonesia Jadi Tuan Rumah P...  negatif
# 14804  @Metro_TV 3043 guru PI PPPK se-Indonesia dan T...   netral
# 14805  Pemain Timnas Indonesia U-20 ramai-ramai tumpa...  negatif
# 14806  Politikus PDIP Budiman Sudjatmiko mengatakan, ...  positif
#
#                                              CaseFolding  \
# 0      @ch_chotimah2 @dennysiregar7 @erickthohir @jok...
# 1      gagalnya perhelatan piala dunia u-20 di indone...
# 2      @tatakujiyati tapi @aniesbaswedan kan sering m...
# 3      dicoret sebagai tuan rumah piala dunia u-20, b...
# 4      ketua umum erick thohir mengungkapkan alasan f...
# ...                                                  ...
# 14802  piala dunia u-20 batal digelar di indonesia ht...
# 14803  4 tahun perjuangan indonesia jadi tuan rumah p...
# 14804  @metro_tv 3043 guru pi pppk se-indonesia dan t...
# 14805  pemain timnas indonesia u-20 ramai-ramai tumpa...
# 14806  politikus pdip budiman sudjatmiko mengatakan, ...
#
#                                                TextClean  \
# 0      lupakan kegagalan tuan rumah piala dunia  mari...
# 1      gagalnya perhelatan piala dunia  di indonesia ...
# 2      tapi kan sering mencitrakan diri sgt membela p...
# 3      dicoret sebagai tuan rumah piala dunia  bentar...
# 4      ketua umum erick thohir mengungkapkan alasan f...
# ...                                                  ...
# 14802            piala dunia  batal digelar di indonesia
# 14803  tahun perjuangan indonesia jadi tuan rumah pia...
# 14804  guru pi pppk seindonesia dan tuan rumah piala ...
# 14805  pemain timnas indonesia  ramairamai tumpahkan ...
# 14806  politikus pdip budiman sudjatmiko mengatakan p...
#
#                                                   tokens  \
# 0      [lupakan, kegagalan, tuan, rumah, piala, dunia...
# 1      [gagalnya, perhelatan, piala, dunia, di, indon...
# 2      [tapi, kan, sering, mencitrakan, diri, sgt, me...
# 3      [dicoret, sebagai, tuan, rumah, piala, dunia, ...
# 4      [ketua, umum, erick, thohir, mengungkapkan, al...
# ...                                                  ...
# 14802      [piala, dunia, batal, digelar, di, indonesia]
# 14803  [tahun, perjuangan, indonesia, jadi, tuan, rum...
# 14804  [guru, pi, pppk, seindonesia, dan, tuan, rumah...
# 14805  [pemain, timnas, indonesia, ramairamai, tumpah...
# 14806  [politikus, pdip, budiman, sudjatmiko, mengata...
#
#                                              normalisasi
# 0      [lupakan, kegagalan, tuan, rumah, piala, dunia...
# 1      [gagalnya, perhelatan, piala, dunia, di, indon...
# 2      [tetapi, kan, sering, mencitrakan, diri, sanga...
# 3      [dicoret, sebagai, tuan, rumah, piala, dunia, ...
# 4      [ketua, umum, erick, thohir, mengungkapkan, al...
# ...                                                  ...
# 14802      [piala, dunia, batal, digelar, di, indonesia]
# 14803  [tahun, perjuangan, indonesia, jadi, tuan, rum...
# 14804  [guru, pi, pppk, seindonesia, dan, tuan, rumah...
# 14805  [pemain, timnas, indonesia,  ramai ramai, tump...
# 14806  [politikus, pdip, budiman, sudjatmiko, mengata...
#
# [14807 rows x 6 columns]

# %% [markdown]
# ## StwopWord

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\arman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("/Users/arman/Skripsi/stopwords-id.txt", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['stopword'] = df['normalisasi'].apply(stopwords_removal) 


print(df['stopword'].head())
# Out:
# 0    [lupakan, kegagalan, tuan, rumah, piala, dunia...
# 1    [gagalnya, perhelatan, piala, dunia, indonesia...
# 2    [mencitrakan, membela,  palestina menggunakan,...
# 3    [tuan, rumah, piala, dunia, bentar, tuan, ruma...
# 4    [ketua, erick, thohir, alasan, fifa, membatalk...
# Name: stopword, dtype: object

# %%
list_stopwords
# Out:
# {'&amp',
#  'aaaaa',
#  'aargh',
#  'ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'agv',
#  'ahhh',
#  'ai',
#  'aja',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'amp',
#  'amputmmediumsocialamputmsourcetwitter',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'awokawokaowk',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'baghowi',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'basabasi',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
#  'berakhirnya',
#  'berapa',
#  'berapakah',
#  'berapalah',
#  'berapapun',
#  'berarti',
#  'berawal',
#  'berbagai',
#  'berdatangan',
#  'beri',
#  'berikan',
#  'berikut',
#  'berikutnya',
#  'berjumlah',
#  'berkali-kali',
#  'berkata',
#  'berkehendak',
#  'berkeinginan',
#  'berkenaan',
#  'berlainan',
#  'berlalu',
#  'berlangsung',
#  'berlebihan',
#  'bermacam',
#  'bermacam-macam',
#  'bermaksud',
#  'bermula',
#  'bersama',
#  'bersama-sama',
#  'bersiap',
#  'bersiap-siap',
#  'bertanya',
#  'bertanya-tanya',
#  'berturut',
#  'berturut-turut',
#  'bertutur',
#  'berujar',
#  'berupa',
#  'besar',
#  'betul',
#  'betulkah',
#  'bgddd',
#  'biar',
#  'biasa',
#  'biasanya',
#  'bikin',
#  'bila',
#  'bilakah',
#  'bilang',
#  'bisa',
#  'bisakah',
#  'bnjiri',
#  'boleh',
#  'bolehkah',
#  'bolehlah',
#  'buahahahahahasampe',
#  'buat',
#  'bukan',
#  'bukankah',
#  'bukanlah',
#  'bukannya',
#  'bulan',
#  'bung',
#  'caiiii',
#  'cara',
#  'caranya',
#  'cc',
#  'chakzzz',
#  'chuaaaakzzzzz',
#  'chuaaakksss',
#  'chuaakkkssss',
#  'chuaks',
#  'chuakss',
#  'chuakzzz',
#  'chukwuemeka',
#  'cieee',
#  'cmiiw',
#  'cni',
#  'cpw',
#  'cuakkks',
#  'cukup',
#  'cukupkah',
#  'cukuplah',
#  'cuma',
#  'd',
#  'dahulu',
#  'dalam',
#  'dan',
#  'dapat',
#  'dari',
#  'daripada',
#  'datang',
#  'dekat',
#  'demi',
#  'demikian',
#  'demikianlah',
#  'dengan',
#  'depan',
#  'dg',
#  'dgn',
#  'di',
#  'dia',
#  'diakhiri',
#  'diakhirinya',
#  'dialah',
#  'diantara',
#  'diantaranya',
#  'diberi',
#  'diberikan',
#  'diberikannya',
#  'dibuat',
#  'dibuatnya',
#  'dicoret',
#  'didapat',
#  'didatangkan',
#  'digunakan',
#  'diibaratkan',
#  'diibaratkannya',
#  'diingat',
#  'diingatkan',
#  'diinginkan',
#  'dijawab',
#  'dijelaskan',
#  'dijelaskannya',
#  'dikarenakan',
#  'dikatakan',
#  'dikatakannya',
#  'dikerjakan',
#  'diketahui',
#  'diketahuinya',
#  'dikira',
#  'dilakukan',
#  'dilalui',
#  'dilihat',
#  'dimaksud',
#  'dimaksudkan',
#  'dimaksudkannya',
#  'dimaksudnya',
#  'diminta',
#  'dimintai',
#  'dimisalkan',
#  'dimulai',
#  'dimulailah',
#  'dimulainya',
#  'dimungkinkan',
#  'dini',
#  'dipastikan',
#  'diperbuat',
#  'diperbuatnya',
#  'dipergunakan',
#  'diperkirakan',
#  'diperlihatkan',
#  'diperlukan',
#  'diperlukannya',
#  'dipersoalkan',
#  'dipertanyakan',
#  'dipunyai',
#  'diri',
#  'dirinya',
#  'disampaikan',
#  'disebut',
#  'disebutkan',
#  'disebutkannya',
#  'disini',
#  'disinilah',
#  'ditambahkan',
#  'ditandaskan',
#  'ditanya',
#  'ditanyai',
#  'ditanyakan',
#  'ditegaskan',
#  'ditujukan',
#  'ditunjuk',
#  'ditunjuki',
#  'ditunjukkan',
#  'ditunjukkannya',
#  'ditunjuknya',
#  'dituturkan',
#  'dituturkannya',
#  'diucapkan',
#  'diucapkannya',
#  'diungkapkan',
#  'dong',
#  'dua',
#  'dulu',
#  'empat',
#  'enggak',
#  'enggaknya',
#  'entah',
#  'entahlah',
#  'fu',
#  'ga',
#  'gak',
#  'gassss',
#  'ge',
#  'getun',
#  'guna',
#  'gunakan',
#  'gung',
#  'gunggg',
#  'guoblokguoblok',
#  'hadehh',
#  'hahahahah',
#  'hahahahahaha',
#  'hahahahahahaha',
#  'hal',
#  'halaaah',
#  'hampir',
#  'hanya',
#  'hanyalah',
#  'hari',
#  'harus',
#  'haruslah',
#  'harusnya',
#  'hca',
#  'hehe',
#  'hehebaru',
#  'heheehee',
#  'hehehe',
#  'hendak',
#  'hendaklah',
#  'hendaknya',
#  'heuheu',
#  'hiiii',
#  'hingga',
#  'hmmmmm',
#  'horeeee',
#  'huhu',
#  'ia',
#  'ialah',
#  'ibarat',
#  'ibaratkan',
#  'ibaratnya',
#  'ibu',
#  'ikntol',
#  'ikut',
#  'ingat',
#  'ingat-ingat',
#  'ingin',
#  'inginkah',
#  'inginkan',
#  'ini',
#  'inikah',
#  'inilah',
#  'itu',
#  'itukah',
#  'itulah',
#  'jadi',
#  'jadilah',
#  'jadinya',
#  'jangan',
#  'jangankan',
#  'janganlah',
#  'jauh',
#  'jawab',
#  'jawaban',
#  'jawabnya',
#  'jd',
#  'jelas',
#  'jelaskan',
#  'jelaslah',
#  'jelasnya',
#  'jgn',
#  'jika',
#  'jikalau',
#  'juga',
#  'jumlah',
#  'jumlahnya',
#  'justru',
#  'kala',
#  'kalau',
#  'kalaulah',
#  'kalaupun',
#  'kalian',
#  'kalo',
#  'kami',
#  'kamilah',
#  'kamu',
#  'kamulah',
#  'kan',
#  'kapan',
#  'kapankah',
#  'kapanpun',
#  'karena',
#  'karenanya',
#  'kasus',
#  'kata',
#  'katakan',
#  'katakanlah',
#  'katanya',
#  'ke',
#  'keadaan',
#  'kebetulan',
#  'kecil',
#  'kedua',
#  'keduanya',
#  'keinginan',
#  'kelamaan',
#  'kelihatan',
#  'kelihatannya',
#  'kelima',
#  'keluar',
#  'kembali',
#  'kemudian',
#  'kemungkinan',
#  'kemungkinannya',
#  'kenapa',
#  'kepada',
#  'kepadanya',
#  'kesampaian',
#  'keseluruhan',
#  'keseluruhannya',
#  'keterlaluan',
#  'ketika',
#  'khususnya',
#  'kini',
#  'kinilah',
#  'kira',
#  'kira-kira',
#  'kiranya',
#  'kita',
#  'kitalah',
#  'klo',
#  'kok',
#  'kqs',
#  'krn',
#  'kurang',
#  'lagi',
#  'lagian',
#  'lah',
#  'lain',
#  'lainnya',
#  'lalu',
#  'lama',
#  'lamanya',
#  'lan',
#  'lanjut',
#  'lanjutnya',
#  'le',
#  'lebih',
#  'lewat',
#  'lima',
#  'loh',
#  'loohh',
#  'luar',
#  'macam',
#  'maka',
#  'makanya',
#  'makin',
#  'malah',
#  'malahan',
#  'mamam',
#  'mampu',
#  'mampukah',
#  'mana',
#  'manakala',
#  'manalagi',
#  'masa',
#  'masalah',
#  'masalahnya',
#  'masih',
#  'masihkah',
#  'masing',
#  'masing-masing',
#  'mau',
#  'maupun',
#  'melainkan',
#  'melakukan',
#  'melalui',
#  'melihat',
#  'melihatnya',
#  'memang',
#  'memastikan',
#  'memberi',
#  'memberikan',
#  'membuat',
#  'memerlukan',
#  'memihak',
#  'meminta',
#  'memintakan',
#  'memisalkan',
#  'memperbuat',
#  'mempergunakan',
#  'memperkirakan',
#  'memperlihatkan',
#  'mempersiapkan',
#  'mempersoalkan',
#  'mempertanyakan',
#  'mempunyai',
#  'memulai',
#  'memungkinkan',
#  'menaiki',
#  'menambahkan',
#  'menandaskan',
#  'menanti',
#  'menanti-nanti',
#  'menantikan',
#  'menanya',
#  'menanyai',
#  'menanyakan',
#  'mendapat',
#  'mendapatkan',
#  'mendatang',
#  'mendatangi',
#  'mendatangkan',
#  'menegaskan',
#  'mengakhiri',
#  'mengapa',
#  'mengatakan',
#  'mengatakannya',
#  'mengenai',
#  'mengerjakan',
#  'mengetahui',
#  'menggunakan',
#  'menghendaki',
#  'mengibaratkan',
#  'mengibaratkannya',
#  'mengingat',
#  'mengingatkan',
#  'menginginkan',
#  'mengira',
#  'mengucapkan',
#  'mengucapkannya',
#  'mengungkapkan',
#  'menjadi',
#  'menjawab',
#  'menjelaskan',
#  'menuju',
#  'menunjuk',
#  'menunjuki',
#  'menunjukkan',
#  'menunjuknya',
#  'menurut',
#  'menuturkan',
#  'menyampaikan',
#  'menyangkut',
#  'menyatakan',
#  'menyebutkan',
#  'menyeluruh',
#  'menyiapkan',
#  'merasa',
#  'mereka',
#  'merekalah',
#  'merupakan',
#  'meski',
#  'meskipun',
#  'meyakini',
#  'meyakinkan',
#  'minta',
#  'mirip',
#  'misal',
#  'misalkan',
#  'misalnya',
#  'mmc',
#  'mula',
#  'mulai',
#  'mulailah',
#  'mulanya',
#  'mungkin',
#  'mungkinkah',
#  'n',
#  'nah',
#  'naik',
#  'namun',
#  'nan',
#  'nanti',
#  'nantinya',
#  'naskleenggg',
#  'nih',
#  'nul',
#  'ny',
#  'nya',
#  'nyaris',
#  'nyatanya',
#  'nyg',
#  'oiya',
#  'okela',
#  'oleh',
#  'olehnya',
#  'pada',
#  'padahal',
#  'padanya',
#  'pak',
#  'paling',
#  'panjang',
#  'pantas',
#  'para',
#  'pasti',
#  'pastilah',
#  'pdip',
#  'pen',
#  'penting',
#  'pentingnya',
#  'per',
#  'percuma',
#  'perlu',
#  'perlukah',
#  'perlunya',
#  'pernah',
#  'persoalan',
#  'pertama',
#  'pertama-tama',
#  'pertanyaan',
#  'pertanyakan',
#  'pi',
#  'pihak',
#  'pihaknya',
#  'pksniidkk',
#  'pppk',
#  'pukul',
#  'pula',
#  'pun',
#  'punya',
#  'quf',
#  'rasa',
#  'rasanya',
#  'rata',
#  'rt',
#  'rupanya',
#  'sa',
#  'saat',
#  'saatnya',
#  'saja',
#  'sajalah',
#  'saling',
#  'sama',
#  'sama-sama',
#  'sambil',
#  'sampai',
#  'sampai-sampai',
#  'sampaikan',
#  'sana',
#  'sanaaaa',
#  'sangat',
#  'sangatlah',
#  'satu',
#  'saya',
#  'sayalah',
#  'sbghostamp',
#  'sdh',
#  'se',
#  'sebab',
#  'sebabnya',
#  'sebagai',
#  'sebagaimana',
#  'sebagainya',
#  'sebagian',
#  'sebaik',
#  'sebaik-baiknya',
#  'sebaiknya',
#  'sebaliknya',
#  'sebanyak',
#  'sebegini',
#  'sebegitu',
#  'sebelum',
#  'sebelumnya',
#  'sebenarnya',
#  'seberapa',
#  'sebesar',
#  'sebetulnya',
#  'sebisanya',
#  'sebuah',
#  'sebut',
#  'sebutlah',
#  'sebutnya',
#  'secara',
#  'secukupnya',
#  'sedang',
#  'sedangkan',
#  'sedemikian',
#  'sedikit',
#  'sedikitnya',
#  'seenaknya',
#  'segala',
#  'segalanya',
#  'segera',
#  'seharusnya',
#  'sehingga',
#  'seingat',
#  'sejak',
#  'sejauh',
#  'sejenak',
#  'sejumlah',
#  'sekadar',
#  'sekadarnya',
#  'sekali',
#  'sekali-kali',
#  'sekalian',
#  'sekaligus',
#  'sekalipun',
#  'sekarang',
#  'sekecil',
#  'seketika',
#  'sekiranya',
#  'sekitar',
#  'sekitarnya',
#  'sekurang-kurangnya',
#  'sekurangnya',
#  'sela',
#  'selagi',
#  'selain',
#  'selaku',
#  'selalu',
#  'selama',
#  'selama-lamanya',
#  'selamanya',
#  'selanjutnya',
#  'seluruh',
#  'seluruhnya',
#  'semacam',
#  'semakin',
#  'semampu',
#  'semampunya',
#  'semasa',
#  'semasih',
#  'semata',
#  'semata-mata',
#  'semaunya',
#  'sementara',
#  'semisal',
#  'semisalnya',
#  'sempat',
#  'semua',
#  'semuanya',
#  'semula',
#  'sendiri',
#  'sendirian',
#  'sendirinya',
#  'seolah',
#  'seolah-olah',
#  'seorang',
#  'sepanjang',
#  'sepantasnya',
#  'sepantasnyalah',
#  'seperlunya',
#  'seperti',
#  'sepertinya',
#  'sepihak',
#  'sering',
#  'seringnya',
#  'serta',
#  'serupa',
#  'sesaat',
#  'sesama',
#  'sesampai',
#  'sesegera',
#  'sesekali',
#  'seseorang',
#  'sesuatu',
#  'sesuatunya',
#  'sesudah',
#  'sesudahnya',
#  'setelah',
#  'setempat',
#  'setengah',
#  'seterusnya',
#  'setiap',
#  'setiba',
#  'setibanya',
#  'setidak-tidaknya',
#  'setidaknya',
#  'setinggi',
#  'seusai',
#  'sewaktu',
#  'si',
#  'siap',
#  'siapa',
#  'siapakah',
#  'siapapun',
#  'sih',
#  'sihhh',
#  'sini',
#  'sinilah',
#  'siregarxix',
#  'soal',
#  'soalnya',
#  'suatu',
#  'sudah',
#  'sudahkah',
#  'sudahlah',
#  'supaya',
#  't',
#  'tadi',
#  'tadinya',
#  'tahu',
#  'tahun',
#  'tak',
#  'tambah',
#  'tambahnya',
#  'tampak',
#  'tampaknya',
#  'tandas',
#  'tandasnya',
#  'tanpa',
#  'tanya',
#  'tanyakan',
#  'tanyanya',
#  'tapi',
#  'tau',
#  'tdk',
#  'tegas',
#  'tegasnya',
#  'telah',
#  'tempat',
#  'tengah',
#  'tentang',
#  'tentu',
#  'tentulah',
#  'tentunya',
#  'tepat',
#  'terakhir',
#  'terasa',
#  'terbanyak',
#  'terdahulu',
#  'terdapat',
#  'terdiri',
#  'terhadap',
#  'terhadapnya',
#  'teringat',
#  'teringat-ingat',
#  'terjadi',
#  'terjadilah',
#  'terjadinya',
#  'terkira',
#  'terlalu',
#  'terlebih',
#  'terlihat',
#  'termasuk',
#  'ternyata',
#  'tersampaikan',
#  'tersebut',
#  'tersebutlah',
#  'tertentu',
#  'tertuju',
#  'terus',
#  'terutama',
#  'tetap',
#  'tetapi',
#  'tiap',
#  'tiba',
#  'tiba-tiba',
#  'tidak',
#  'tidakkah',
#  'tidaklah',
#  'tiga',
#  'tinggi',
#  'tmr',
#  'toh',
#  'tuh',
#  'tunjuk',
#  'turut',
#  'tutur',
#  'tuturnya',
#  'u',
#  'ucap',
#  'ucapnya',
#  'ujar',
#  'ujarnya',
#  'umum',
#  'umumnya',
#  'ungkap',
#  'ungkapnya',
#  'untuk',
#  'usah',
#  'usai',
#  'utk',
#  'waduh',
#  'wah',
#  'wahai',
#  'waktu',
#  'waktunya',
#  'walau',
#  'walaupun',
#  'whehehe',
#  'wkwkk',
#  'wkwkkwkwkw',
#  'wkwkwk',
#  'wkwkwkkwkwk',
#  'wkwkwkwk',
#  'woii',
#  'wong',
#  'wooiii',
#  'wwkwk',
#  'wxp',
#  'xi',
#  'xixiix',
#  'xje',
#  'xxix',
#  'ya',
#  'yah',
#  'yahh',
#  'yaitu',
#  'yakin',
#  'yakni',
#  'yang',
#  'yed',
#  'yg'}

# %%
df
# Out:
#                                                     Text    Label  \
# 0      @ch_chotimah2 @Dennysiregar7 @erickthohir @jok...  negatif
# 1      Gagalnya perhelatan piala dunia U-20 di Indone...  positif
# 2      @tatakujiyati Tapi @aniesbaswedan kan sering m...  negatif
# 3      Dicoret sebagai tuan rumah piala dunia U-20, b...   netral
# 4      Ketua umum Erick Thohir mengungkapkan alasan F...   netral
# ...                                                  ...      ...
# 14802  Piala Dunia U-20 Batal Digelar di Indonesia ht...   netral
# 14803  4 Tahun Perjuangan Indonesia Jadi Tuan Rumah P...  negatif
# 14804  @Metro_TV 3043 guru PI PPPK se-Indonesia dan T...   netral
# 14805  Pemain Timnas Indonesia U-20 ramai-ramai tumpa...  negatif
# 14806  Politikus PDIP Budiman Sudjatmiko mengatakan, ...  positif
#
#                                              CaseFolding  \
# 0      @ch_chotimah2 @dennysiregar7 @erickthohir @jok...
# 1      gagalnya perhelatan piala dunia u-20 di indone...
# 2      @tatakujiyati tapi @aniesbaswedan kan sering m...
# 3      dicoret sebagai tuan rumah piala dunia u-20, b...
# 4      ketua umum erick thohir mengungkapkan alasan f...
# ...                                                  ...
# 14802  piala dunia u-20 batal digelar di indonesia ht...
# 14803  4 tahun perjuangan indonesia jadi tuan rumah p...
# 14804  @metro_tv 3043 guru pi pppk se-indonesia dan t...
# 14805  pemain timnas indonesia u-20 ramai-ramai tumpa...
# 14806  politikus pdip budiman sudjatmiko mengatakan, ...
#
#                                                TextClean  \
# 0      lupakan kegagalan tuan rumah piala dunia  mari...
# 1      gagalnya perhelatan piala dunia  di indonesia ...
# 2      tapi kan sering mencitrakan diri sgt membela p...
# 3      dicoret sebagai tuan rumah piala dunia  bentar...
# 4      ketua umum erick thohir mengungkapkan alasan f...
# ...                                                  ...
# 14802            piala dunia  batal digelar di indonesia
# 14803  tahun perjuangan indonesia jadi tuan rumah pia...
# 14804  guru pi pppk seindonesia dan tuan rumah piala ...
# 14805  pemain timnas indonesia  ramairamai tumpahkan ...
# 14806  politikus pdip budiman sudjatmiko mengatakan p...
#
#                                                   tokens  \
# 0      [lupakan, kegagalan, tuan, rumah, piala, dunia...
# 1      [gagalnya, perhelatan, piala, dunia, di, indon...
# 2      [tapi, kan, sering, mencitrakan, diri, sgt, me...
# 3      [dicoret, sebagai, tuan, rumah, piala, dunia, ...
# 4      [ketua, umum, erick, thohir, mengungkapkan, al...
# ...                                                  ...
# 14802      [piala, dunia, batal, digelar, di, indonesia]
# 14803  [tahun, perjuangan, indonesia, jadi, tuan, rum...
# 14804  [guru, pi, pppk, seindonesia, dan, tuan, rumah...
# 14805  [pemain, timnas, indonesia, ramairamai, tumpah...
# 14806  [politikus, pdip, budiman, sudjatmiko, mengata...
#
#                                              normalisasi  \
# 0      [lupakan, kegagalan, tuan, rumah, piala, dunia...
# 1      [gagalnya, perhelatan, piala, dunia, di, indon...
# 2      [tetapi, kan, sering, mencitrakan, diri, sanga...
# 3      [dicoret, sebagai, tuan, rumah, piala, dunia, ...
# 4      [ketua, umum, erick, thohir, mengungkapkan, al...
# ...                                                  ...
# 14802      [piala, dunia, batal, digelar, di, indonesia]
# 14803  [tahun, perjuangan, indonesia, jadi, tuan, rum...
# 14804  [guru, pi, pppk, seindonesia, dan, tuan, rumah...
# 14805  [pemain, timnas, indonesia,  ramai ramai, tump...
# 14806  [politikus, pdip, budiman, sudjatmiko, mengata...
#
#                                                 stopword
# 0      [lupakan, kegagalan, tuan, rumah, piala, dunia...
# 1      [gagalnya, perhelatan, piala, dunia, indonesia...
# 2      [mencitrakan, membela,  palestina menggunakan,...
# 3      [tuan, rumah, piala, dunia, bentar, tuan, ruma...
# 4      [ketua, erick, thohir, alasan, fifa, membatalk...
# ...                                                  ...
# 14802          [piala, dunia, batal, digelar, indonesia]
# 14803  [perjuangan, indonesia, tuan, rumah, piala, du...
# 14804  [guru, seindonesia, tuan, rumah, piala, dunia,...
# 14805  [pemain, timnas, indonesia,  ramai ramai, tump...
# 14806  [politikus, budiman, sudjatmiko, menolak, timn...
#
# [14807 rows x 7 columns]

# %%
df.to_csv('/Users/arman/Skripsi/Dataset/BigData/Fix/Piala-Dunia-Label-stopword.csv')

# %% [markdown]
# ## Steaming Data

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()
 
def steming(text):
    text = stemmer.stem(text)
    return text

# %%
df1 = pd.read_csv('/Users/arman/Skripsi/Dataset/BigData/Fix/Piala-Dunia-Label-stopword.csv')
df1
# Out:
#        Unnamed: 0                                               Text    Label  \
# 0               0  @ch_chotimah2 @Dennysiregar7 @erickthohir @jok...  negatif
# 1               1  Gagalnya perhelatan piala dunia U-20 di Indone...  positif
# 2               2  @tatakujiyati Tapi @aniesbaswedan kan sering m...  negatif
# 3               3  Dicoret sebagai tuan rumah piala dunia U-20, b...   netral
# 4               4  Ketua umum Erick Thohir mengungkapkan alasan F...   netral
# ...           ...                                                ...      ...
# 14802       14802  Piala Dunia U-20 Batal Digelar di Indonesia ht...   netral
# 14803       14803  4 Tahun Perjuangan Indonesia Jadi Tuan Rumah P...  negatif
# 14804       14804  @Metro_TV 3043 guru PI PPPK se-Indonesia dan T...   netral
# 14805       14805  Pemain Timnas Indonesia U-20 ramai-ramai tumpa...  negatif
# 14806       14806  Politikus PDIP Budiman Sudjatmiko mengatakan, ...  positif
#
#                                              CaseFolding  \
# 0      @ch_chotimah2 @dennysiregar7 @erickthohir @jok...
# 1      gagalnya perhelatan piala dunia u-20 di indone...
# 2      @tatakujiyati tapi @aniesbaswedan kan sering m...
# 3      dicoret sebagai tuan rumah piala dunia u-20, b...
# 4      ketua umum erick thohir mengungkapkan alasan f...
# ...                                                  ...
# 14802  piala dunia u-20 batal digelar di indonesia ht...
# 14803  4 tahun perjuangan indonesia jadi tuan rumah p...
# 14804  @metro_tv 3043 guru pi pppk se-indonesia dan t...
# 14805  pemain timnas indonesia u-20 ramai-ramai tumpa...
# 14806  politikus pdip budiman sudjatmiko mengatakan, ...
#
#                                                TextClean  \
# 0      lupakan kegagalan tuan rumah piala dunia  mari...
# 1      gagalnya perhelatan piala dunia  di indonesia ...
# 2      tapi kan sering mencitrakan diri sgt membela p...
# 3      dicoret sebagai tuan rumah piala dunia  bentar...
# 4      ketua umum erick thohir mengungkapkan alasan f...
# ...                                                  ...
# 14802            piala dunia  batal digelar di indonesia
# 14803  tahun perjuangan indonesia jadi tuan rumah pia...
# 14804  guru pi pppk seindonesia dan tuan rumah piala ...
# 14805  pemain timnas indonesia  ramairamai tumpahkan ...
# 14806  politikus pdip budiman sudjatmiko mengatakan p...
#
#                                                   tokens  \
# 0      ['lupakan', 'kegagalan', 'tuan', 'rumah', 'pia...
# 1      ['gagalnya', 'perhelatan', 'piala', 'dunia', '...
# 2      ['tapi', 'kan', 'sering', 'mencitrakan', 'diri...
# 3      ['dicoret', 'sebagai', 'tuan', 'rumah', 'piala...
# 4      ['ketua', 'umum', 'erick', 'thohir', 'mengungk...
# ...                                                  ...
# 14802  ['piala', 'dunia', 'batal', 'digelar', 'di', '...
# 14803  ['tahun', 'perjuangan', 'indonesia', 'jadi', '...
# 14804  ['guru', 'pi', 'pppk', 'seindonesia', 'dan', '...
# 14805  ['pemain', 'timnas', 'indonesia', 'ramairamai'...
# 14806  ['politikus', 'pdip', 'budiman', 'sudjatmiko',...
#
#                                              normalisasi  \
# 0      ['lupakan', 'kegagalan', 'tuan', 'rumah', 'pia...
# 1      ['gagalnya', 'perhelatan', 'piala', 'dunia', '...
# 2      ['tetapi', 'kan', 'sering', 'mencitrakan', 'di...
# 3      ['dicoret', 'sebagai', 'tuan', 'rumah', 'piala...
# 4      ['ketua', 'umum', 'erick', 'thohir', 'mengungk...
# ...                                                  ...
# 14802  ['piala', 'dunia', 'batal', 'digelar', 'di', '...
# 14803  ['tahun', 'perjuangan', 'indonesia', 'jadi', '...
# 14804  ['guru', 'pi', 'pppk', 'seindonesia', 'dan', '...
# 14805  ['pemain', 'timnas', 'indonesia', ' ramai rama...
# 14806  ['politikus', 'pdip', 'budiman', 'sudjatmiko',...
#
#                                                 stopword
# 0      ['lupakan', 'kegagalan', 'tuan', 'rumah', 'pia...
# 1      ['gagalnya', 'perhelatan', 'piala', 'dunia', '...
# 2      ['mencitrakan', 'membela', ' palestina menggun...
# 3      ['tuan', 'rumah', 'piala', 'dunia', 'bentar', ...
# 4      ['ketua', 'erick', 'thohir', 'alasan', 'fifa',...
# ...                                                  ...
# 14802  ['piala', 'dunia', 'batal', 'digelar', 'indone...
# 14803  ['perjuangan', 'indonesia', 'tuan', 'rumah', '...
# 14804  ['guru', 'seindonesia', 'tuan', 'rumah', 'pial...
# 14805  ['pemain', 'timnas', 'indonesia', ' ramai rama...
# 14806  ['politikus', 'budiman', 'sudjatmiko', 'menola...
#
# [14807 rows x 8 columns]

# %%
df1['Steming'] = df1['stopword'].apply(steming)
df1.head()
# Out:
#    Unnamed: 0                                               Text    Label  \
# 0           0  @ch_chotimah2 @Dennysiregar7 @erickthohir @jok...  negatif
# 1           1  Gagalnya perhelatan piala dunia U-20 di Indone...  positif
# 2           2  @tatakujiyati Tapi @aniesbaswedan kan sering m...  negatif
# 3           3  Dicoret sebagai tuan rumah piala dunia U-20, b...   netral
# 4           4  Ketua umum Erick Thohir mengungkapkan alasan F...   netral
#
#                                          CaseFolding  \
# 0  @ch_chotimah2 @dennysiregar7 @erickthohir @jok...
# 1  gagalnya perhelatan piala dunia u-20 di indone...
# 2  @tatakujiyati tapi @aniesbaswedan kan sering m...
# 3  dicoret sebagai tuan rumah piala dunia u-20, b...
# 4  ketua umum erick thohir mengungkapkan alasan f...
#
#                                            TextClean  \
# 0  lupakan kegagalan tuan rumah piala dunia  mari...
# 1  gagalnya perhelatan piala dunia  di indonesia ...
# 2  tapi kan sering mencitrakan diri sgt membela p...
# 3  dicoret sebagai tuan rumah piala dunia  bentar...
# 4  ketua umum erick thohir mengungkapkan alasan f...
#
#                                               tokens  \
# 0  ['lupakan', 'kegagalan', 'tuan', 'rumah', 'pia...
# 1  ['gagalnya', 'perhelatan', 'piala', 'dunia', '...
# 2  ['tapi', 'kan', 'sering', 'mencitrakan', 'diri...
# 3  ['dicoret', 'sebagai', 'tuan', 'rumah', 'piala...
# 4  ['ketua', 'umum', 'erick', 'thohir', 'mengungk...
#
#                                          normalisasi  \
# 0  ['lupakan', 'kegagalan', 'tuan', 'rumah', 'pia...
# 1  ['gagalnya', 'perhelatan', 'piala', 'dunia', '...
# 2  ['tetapi', 'kan', 'sering', 'mencitrakan', 'di...
# 3  ['dicoret', 'sebagai', 'tuan', 'rumah', 'piala...
# 4  ['ketua', 'umum', 'erick', 'thohir', 'mengungk...
#
#                                             stopword  \
# 0  ['lupakan', 'kegagalan', 'tuan', 'rumah', 'pia...
# 1  ['gagalnya', 'perhelatan', 'piala', 'dunia', '...
# 2  ['mencitrakan', 'membela', ' palestina menggun...
# 3  ['tuan', 'rumah', 'piala', 'dunia', 'bentar', ...
# 4  ['ketua', 'erick', 'thohir', 'alasan', 'fifa',...
#
#                                              Steming
# 0  lupa gagal tuan rumah piala dunia mari tata se...
# 1  gagal helat piala dunia indonesia jadi alam de...
# 2  citra bela palestina guna syal palestina baca ...
# 3       tuan rumah piala dunia bentar tuan rumah wbg
# 4  ketua erick thohir alas fifa batal posisi indo...

# %%
keep_col = ['Steming','Label']
df1 = df1[keep_col]
df1.to_csv('/Users/arman/Skripsi/Dataset/BigData/Fix/Piala-Dunia-Label-Clean.csv')

# %% [markdown]
# ## Menghapus Data set Duplicate

# %%
# df.drop_duplicates(subset='Steming', keep = 'first', inplace = True)
# # df1

# %%
# pd.value_counts(df1['Label'])
